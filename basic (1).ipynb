# %% [markdown]
# ## load the dataset

# %%
import numpy as np
import pandas as pd
df= pd.read_csv(r"C:\Users\student\Downloads\Housing (1).csv")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# ## rows and columns

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# ## visualize the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# ## checking the missing values

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# ## summary statistics

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %% [markdown]
# ## encoding the categorical columns

# %%
if 'guestroom' in df.columns:
    df['guestroom'] = df['guestroom'].apply(lambda x: 1 if x == 'yes' else 0)

# %% [markdown]
# by changing the guestroom into 1 for yes and 0 for no

# %%
print(df['guestroom'].head(6))
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# 5    0
# Name: guestroom, dtype: int64

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
print(df.select_dtypes(include=['number']))
# Out:
#         price  area  bedrooms  bathrooms  stories  guestroom  parking
# 0    13300000  7420         4          2        3          0        2
# 1    12250000  8960         4          4        4          0        3
# 2    12250000  9960         3          2        2          0        2
# 3    12215000  7500         4          2        2          0        3
# 4    11410000  7420         4          1        2          1        2
# ..        ...   ...       ...        ...      ...        ...      ...
# 540   1820000  3000         2          1        1          0        2
# 541   1767150  2400         3          1        1          0        0
# 542   1750000  3620         2          1        1          0        0
# 543   1750000  2910         3          1        1          0        0
# 544   1750000  3850         3          1        2          0        0
#
# [545 rows x 7 columns]

# %% [markdown]
# ## visualize the pairplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.show()

# %% [markdown]
# by the pairplot we know that there is high relationship between area and price

# %% [markdown]
# ## visualize the correlation through the heatmap

# %%
a=df.select_dtypes(include=['number'])
sns.heatmap(a.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# high correlation is between price and area

# %% [markdown]
# ## boxplot

# %%
sns.boxplot(x='airconditioning', y='furnishingstatus', data=df)
plt.show()

# %% [markdown]
# from this we know that highly air condition is yes based on furnished,semi-furnished

# %% [markdown]
# ## countplot

# %%
sns.countplot(x='furnishingstatus',data=df)
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='count'>

# %% [markdown]
# from this we know that highly semi furnished is available

# %%
categorical_columns = ['mainroad','basement', 'hotwaterheating', 'airconditioning', 'prefarea']
for col in categorical_columns:
    if col in df.columns:
        df[col] = df[col].apply(lambda x: 1 if x == 'yes' else 0)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         0          0
# 1  12250000  8960         4          4        4         0          0
# 2  12250000  9960         3          2        2         0          0
# 3  12215000  7500         4          2        2         0          0
# 4  11410000  7420         4          1        2         0          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                0        2         0
# 1         0                0                0        3         0
# 2         0                0                0        2         0
# 3         0                0                0        3         0
# 4         0                0                0        2         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
if 'furnishingstatus' in df.columns:
    df['furnishingstatus'] = df['furnishingstatus'].map({'furnished': 2, 'semi-furnished': 1, 'unfurnished': 0})

# %%
df.furnishingstatus
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      2
#       ..
# 540    0
# 541    1
# 542    0
# 543    2
# 544    0
# Name: furnishingstatus, Length: 545, dtype: int64

# %% [markdown]
# ## to visualize the strong relationship

# %%
a= df.corr()['furnishingstatus']
print(a)
# Out:
# price               0.304721
# area                0.171445
# bedrooms            0.123244
# bathrooms           0.143559
# stories             0.104672
# mainroad                 NaN
# guestroom           0.118328
# basement                 NaN
# hotwaterheating          NaN
# airconditioning          NaN
# parking             0.177539
# prefarea                 NaN
# furnishingstatus    1.000000
# Name: furnishingstatus, dtype: float64

# %%
sort = a.sort_values(ascending=False)
print(sort)
# Out:
# furnishingstatus    1.000000
# price               0.304721
# parking             0.177539
# area                0.171445
# bathrooms           0.143559
# bedrooms            0.123244
# guestroom           0.118328
# stories             0.104672
# mainroad                 NaN
# basement                 NaN
# hotwaterheating          NaN
# airconditioning          NaN
# prefarea                 NaN
# Name: furnishingstatus, dtype: float64

# %% [markdown]
# from this we know that highly relationship is between the price and furnishingstatus
