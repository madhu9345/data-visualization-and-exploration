# %% [markdown]
# <a href="https://colab.research.google.com/github/madhu9345/data-visualization-and-exploration/blob/main/data_quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **description**:
# This dataset contains information about books, including their publishing year, title, authors, language, ratings, sales figures, and publisher details. Here's a breakdown of the columns in the dataset:
#
# Index: A unique identifier for each book entry in the dataset.
#
# Publishing Year: The year the book was published.
#
# Book Name: The title of the book.
#
# Author: The author(s) of the book. Some entries contain multiple authors.
#
# Language Code: The language code of the book (e.g., "en-US" for English).
#
# Author Rating: A rating for the author, such as "Novice" or "Intermediate."
#
# Book Average Rating: The average rating of the book based on user reviews.
#
# Book Ratings Count: The total number of ratings the book has received.
#
# Genre: The genre category of the book, such as "fiction" or "genre fiction."
#
# Gross Sales: The total revenue generated by book sales.
#
# Publisher Revenue: The revenue earned by the publisher from the sales of the book.
#
# Sale Price: The price at which the book is sold.
#
# Sales Rank: The book's ranking in terms of sales.
#
# Publisher: The publishing company or service responsible for distributing the book.
#
# Units Sold: The total number of copies of the book sold.

# %%
import pandas as pd
df = pd.read_csv('book.csv')
df
# Out:
#       index  Publishing Year                        Book Name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# ...

# %%
df.head()
# Out:
#    index  Publishing Year                        Book Name  \
# 0      0           1975.0                          Beowulf
# 1      1           1987.0                 Batman: Year One
# 2      2           2015.0                Go Set a Watchman
# 3      3           2008.0  When You Are Engulfed in Flames
# 4      4           2011.0         Daughter of Smoke & Bone
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                         Harper Lee           eng
# 3                                      David Sedaris         en-US
# 4                                       Laini Taylor           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                1070 non-null   int64
#  1   Publishing Year      1069 non-null   float64
#  2   Book Name            1047 non-null   object
#  3   Author               1070 non-null   object
#  4   language_code        1017 non-null   object
#  5   Author_Rating        1070 non-null   object
#  6   Book_average_rating  1070 non-null   float64
#  7   Book_ratings_count   1070 non-null   int64
#  8   genre                1070 non-null   object
#  9   gross sales          1070 non-null   float64
#  10  publisher revenue    1070 non-null   float64
#  11  sale price           1070 non-null   float64
#  12  sales rank           1070 non-null   int64
#  13  Publisher            1070 non-null   object
#  14  units sold           1070 non-null   int64
# ...

# %%
df.describe()
# Out:
#              index  Publishing Year  Book_average_rating  Book_ratings_count  \
# count  1070.000000      1069.000000          1070.000000         1070.000000
# mean    534.500000      1971.377923             4.007000        94909.913084
# std     309.026698       185.080257             0.247244        31513.242518
# min       0.000000      -560.000000             2.970000        27308.000000
# 25%     267.250000      1985.000000             3.850000        70398.000000
# 50%     534.500000      2003.000000             4.015000        89309.000000
# 75%     801.750000      2010.000000             4.170000       113906.500000
# max    1069.000000      2016.000000             4.770000       206792.000000
#
#         gross sales  publisher revenue   sale price   sales rank    units sold
# count   1070.000000        1070.000000  1070.000000  1070.000000   1070.000000
# mean    1856.622944         843.281030     4.869561   611.652336   9676.980374
# ...

# %%
df['Author_Rating'] = df['Author_Rating'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                1070 non-null   int64
#  1   Publishing Year      1069 non-null   float64
#  2   Book Name            1047 non-null   object
#  3   Author               1070 non-null   object
#  4   language_code        1017 non-null   object
#  5   Author_Rating        1070 non-null   category
#  6   Book_average_rating  1070 non-null   float64
#  7   Book_ratings_count   1070 non-null   int64
#  8   genre                1070 non-null   object
#  9   gross sales          1070 non-null   float64
#  10  publisher revenue    1070 non-null   float64
#  11  sale price           1070 non-null   float64
#  12  sales rank           1070 non-null   int64
#  13  Publisher            1070 non-null   object
#  14  units sold           1070 non-null   int64
# ...

# %%
a=df.isnull().sum()
print(a)
# Out:
# index                   0
# Publishing Year         1
# Book Name              23
# Author                  0
# language_code          53
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %%
missing_percentage = df.isnull().mean() * 100
print(missing_percentage)
# Out:
# index                  0.000000
# Publishing Year        0.093458
# Book Name              2.149533
# Author                 0.000000
# language_code          4.953271
# Author_Rating          0.000000
# Book_average_rating    0.000000
# Book_ratings_count     0.000000
# genre                  0.000000
# gross sales            0.000000
# publisher revenue      0.000000
# sale price             0.000000
# sales rank             0.000000
# Publisher              0.000000
# units sold             0.000000
# dtype: float64

# %%
def classify(percentage):
    if percentage == 0:
        return 'No Missing Values (0%)'
    elif 1 <= percentage <= 5:
        return 'Low Missingness (1-5%)'
    elif 5 < percentage <= 20:
        return 'Moderate Missingness (5-20%)'
    else:
        return 'High Missingness (>20%)'


classi = missing_percentage.apply(classify)
print(classi)
# Out:
# index                   No Missing Values (0%)
# Publishing Year        High Missingness (>20%)
# Book Name               Low Missingness (1-5%)
# Author                  No Missing Values (0%)
# language_code           Low Missingness (1-5%)
# Author_Rating           No Missing Values (0%)
# Book_average_rating     No Missing Values (0%)
# Book_ratings_count      No Missing Values (0%)
# genre                   No Missing Values (0%)
# gross sales             No Missing Values (0%)
# publisher revenue       No Missing Values (0%)
# sale price              No Missing Values (0%)
# sales rank              No Missing Values (0%)
# Publisher               No Missing Values (0%)
# units sold              No Missing Values (0%)
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df.isnull(),cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %%
missing_percentage.plot(kind='bar',color='skyblue')
plt.title('Missing Value Percentage for Each Feature')
plt.xlabel('Missing Percentage')
plt.ylabel('Feature')
plt.show()

# %%
df['Publishing Year'].fillna(df['Publishing Year'].mode()[0], inplace=True)


df['Book Name'].fillna('Unknown', inplace=True)


df['language_code'].fillna(df['language_code'].mode()[0], inplace=True)
missing_values_after = df.isnull().sum()
print("Missing Data After Imputation:")
print(missing_values_after)
# Out:
# Missing Data After Imputation:
# index                  0
# Publishing Year        0
# Book Name              0
# Author                 0
# language_code          0
# Author_Rating          0
# Book_average_rating    0
# Book_ratings_count     0
# genre                  0
# gross sales            0
# publisher revenue      0
# sale price             0
# sales rank             0
# Publisher              0
# units sold             0
# dtype: int64
# <ipython-input-14-4e3ad1e53d8d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
categorical_columns = df.select_dtypes(include=['object', 'category']).columns
cardinality = df[categorical_columns].nunique()
print(cardinality)
# Out:
# Book Name        1046
# Author            735
# language_code       8
# Author_Rating       4
# genre               4
# Publisher           9
# dtype: int64

# %%
low_cardinality = cardinality[cardinality < 10]
expected_cardinality = cardinality[(cardinality >= 10) & (cardinality < 1000)]
high_cardinality = cardinality[cardinality >= 1000]

print("Low Cardinality Columns:")
print(low_cardinality)

print("\nExpected Cardinality Columns:")
print(expected_cardinality)

print("\nHigh Cardinality Columns:")
print(high_cardinality)
# Out:
# Low Cardinality Columns:
# language_code    8
# Author_Rating    4
# genre            4
# Publisher        9
# dtype: int64
#
# Expected Cardinality Columns:
# Author    735
# dtype: int64
#
# High Cardinality Columns:
# Book Name    1046
# dtype: int64

# %%
df.columns
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('book.csv')
categorical_columns = ['language_code', 'Author_Rating', 'genre', 'Publisher ']
print("Columns in DataFrame:", df.columns)
for col in categorical_columns:
    if col in df.columns:
        print(f"Unique values in '{col}':", df[col].nunique())
        if df[col].dtype == 'object':
            if df[col].str.isnumeric().any():
                print(f"Warning: Numeric values found in {col}")
    else:
        print(f"Warning: Column '{col}' not found in DataFrame.")



sns.countplot(x='language_code', data=df)
plt.title('Distribution of Language Codes')
plt.show()

sns.countplot(x='Author_Rating', data=df)
plt.title('Distribution of Author Ratings')
plt.show()

sns.countplot(x='genre', data=df)
plt.title('Distribution of Genre')
plt.show()

sns.countplot(x='Publisher ', data=df)
plt.title('Distribution of Publishers')
plt.xticks(rotation=45)
plt.show()
# Out:
# Columns in DataFrame: Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')
# Unique values in 'language_code': 8
# Unique values in 'Author_Rating': 4
# Unique values in 'genre': 4
# Unique values in 'Publisher ': 9

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore


def detect_and_visualize_outliers(df, numerical_columns):
    outlier_results = {}

    for col in numerical_columns:
        print(f"\nChecking for outliers in '{col}'...\n")


        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        iqr_outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        print(f"  IQR Outliers: {len(iqr_outliers)} detected.")

        # Z-score Method
        z_scores = zscore(df[col], nan_policy='omit')  # Handle NaN values
        z_outliers = df[np.abs(z_scores) > 3]
        print(f"  Z-score Outliers: {len(z_outliers)} detected.")

        # Store results
        outlier_results[col] = {
            "IQR_outliers_count": len(iqr_outliers),
            "Z-score_outliers_count": len(z_outliers),
            "IQR_outliers": iqr_outliers,
            "Z-score_outliers": z_outliers
        }

        # Box Plot
        plt.figure(figsize=(8, 4))
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col}')
        plt.xlabel(col)
        plt.show()


        plt.figure(figsize=(8, 4))
        sns.scatterplot(x=df[col], y=df['Book_average_rating'])
        plt.title(f'Scatter Plot of {col} vs. Book Ratings')
        plt.xlabel(col)
        plt.ylabel('Book Average Rating')
        plt.show()

    return outlier_results


numerical_columns = ['Publishing Year', 'Book_average_rating', 'Book_ratings_count',
                     'gross sales', 'publisher revenue', 'sale price', 'sales rank', 'units sold']

 # Call the function
outlier_info = detect_and_visualize_outliers(df, numerical_columns)
# Out:
# Checking for outliers in 'Publishing Year'...
#
#   IQR Outliers: 122 detected.
#   Z-score Outliers: 9 detected.
# Checking for outliers in 'Book_average_rating'...
#
#   IQR Outliers: 16 detected.
#   Z-score Outliers: 7 detected.
# Checking for outliers in 'Book_ratings_count'...
#
#   IQR Outliers: 13 detected.
#   Z-score Outliers: 9 detected.
# Checking for outliers in 'gross sales'...
#
#   IQR Outliers: 129 detected.
#   Z-score Outliers: 21 detected.
# Checking for outliers in 'publisher revenue'...
#
#   IQR Outliers: 95 detected.
#   Z-score Outliers: 19 detected.
# Checking for outliers in 'sale price'...
#
#   IQR Outliers: 8 detected.
#   Z-score Outliers: 5 detected.
# Checking for outliers in 'sales rank'...
#
#   IQR Outliers: 0 detected.
#   Z-score Outliers: 0 detected.
# Checking for outliers in 'units sold'...
#
#   IQR Outliers: 204 detected.
#   Z-score Outliers: 8 detected.

# %%
report = {}

# 1. Missing Value Statistics
missing_data = df.isnull().sum()
missing_percentage = (missing_data / len(df)) * 100
missing_report = pd.DataFrame({
    'Missing Values': missing_data,
    'Percentage': missing_percentage
})
report['Missing Values'] = missing_report[missing_report['Percentage'] > 0]  # Only show features with missing data

# 2. Irregular Cardinality Features
cardinality_report = df.nunique()
high_cardinality = cardinality_report[cardinality_report > 50]  # Features with high cardinality (>50 unique values)
low_cardinality = cardinality_report[cardinality_report < 10]  # Features with low cardinality (<10 unique values)
report['Irregular Cardinality'] = {
    'High Cardinality': high_cardinality,
    'Low Cardinality': low_cardinality
}

# 3. Outlier Summary (using IQR method for numerical features)
outlier_report = {}
for col in df.select_dtypes(include=[np.number]).columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    outlier_report[col] = len(outliers)

report['Outliers'] = pd.DataFrame(list(outlier_report.items()), columns=['Feature', 'Outliers'])

# 4. Data Cleaning Insights and Recommendations
recommendations = []
if len(report['Missing Values']) > 0:
    recommendations.append("Consider imputing missing values for features with significant missing data.")
else:
    recommendations.append("No major missing value issues identified.")

if len(high_cardinality) > 0:
    recommendations.append(f"Consider handling high cardinality features: {', '.join(high_cardinality.index)}.")
if len(low_cardinality) > 0:
    recommendations.append(f"Consider simplifying or consolidating low cardinality features: {', '.join(low_cardinality.index)}.")

if sum(outlier_report.values()) > 0:
    recommendations.append("Consider handling outliers detected using IQR method, especially in features: " +
                           ", ".join([f"{key}: {value}" for key, value in outlier_report.items() if value > 0]))

# Print the structured summary report
print("Structured Summary Report:")
print("\nMissing Value Statistics:")
print(report['Missing Values'])

print("\nIrregular Cardinality Features:")
print("High Cardinality:")
print(report['Irregular Cardinality']['High Cardinality'])
print("Low Cardinality:")
print(report['Irregular Cardinality']['Low Cardinality'])

print("\nOutlier Summary:")
print(report['Outliers'])

print("\nData Cleaning Recommendations:")
for rec in recommendations:
    print(f"- {rec}")
# Out:
# Structured Summary Report:
#
# Missing Value Statistics:
#                  Missing Values  Percentage
# Publishing Year               1    0.093458
# Book Name                    23    2.149533
# language_code                53    4.953271
#
# Irregular Cardinality Features:
# High Cardinality:
# index                  1070
# Publishing Year         150
# Book Name              1045
# Author                  735
# Book_average_rating     134
# Book_ratings_count     1064
# gross sales             831
# publisher revenue       610
# sale price              149
# sales rank              865
# units sold              491
# dtype: int64
# Low Cardinality:
# language_code    8
# Author_Rating    4
# genre            4
# Publisher        9
# dtype: int64
#
# Outlier Summary:
#                Feature  Outliers
# 0                index         0
# 1      Publishing Year       122
# 2  Book_average_rating        16
# 3   Book_ratings_count        13
# 4          gross sales       129
# ...
